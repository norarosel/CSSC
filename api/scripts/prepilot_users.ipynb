# %%
import pymongo
import pandas as pd

# %%
URI = "mongodb://cssc:AUd5H%2aJ44HszzU@lateva:17027/?authSource=cssc&readPreference=primary&appname=MongoDB%20Compass&ssl=false"

myclient = pymongo.MongoClient(URI)
mydb = myclient["cssc"]
mycol = mydb["users"]

# %%
df = pd.read_excel("data/pRRS_prepilot info.xlsx", sheet_name="Profiles", nrows=30)
df.fillna(method="ffill", inplace=True)
df = df[['gender', 'date_of_birth', 'age', 'relation_cancer',
       'relation_descr', 'phase_start_date', 'Year diagnostic', 'cancer_type',
       'topics', 'Description', 'voluntari@s']]
df
# Out:
#     id  gender date_of_birth  age relation_cancer    relation_descr  \
# 0    1  female    1986-04-04   37         patient  active_treatment
# 1    2  female    1955-01-01   68         patient         diagnosis
# 2    3  female    1935-01-02   88         patient      survivorship
# 3    4  female    2000-01-03   23         patient      survivorship
# 4    5  female    1975-01-04   48         patient  active_treatment
# 5    6    male    1989-04-04   34         patient      survivorship
# 6    7    male    1950-01-01   73         patient  active_treatment
# 7    8    male    1952-01-02   71         patient      survivorship
# 8    9    male    1999-01-03   24         patient  active_treatment
# 9   10    male    1969-01-04   54         patient  active_treatment
# 10  11    male    1959-01-05   64         patient         diagnosis
# 11  12    male    1939-01-06   84         patient  active_treatment
# 12  13    male    1989-01-07   34         patient      survivorship
# ...

# %%
df.columns
# Out:
# Index(['id', 'gender', 'date_of_birth', 'age', 'relation_cancer',
#        'relation_descr', 'phase_start_date', 'Year diagnostic', 'cancer_type',
#        'topics', 'Description', 'voluntari@s', 'Cancer Types',
#        'Thematic Areas', 'Unnamed: 14'],
#       dtype='object')

# %%
docs = []

for _, user in df.iterrows():
    doc = user.to_dict()
    doc["username"] = f"{user['voluntari@s']}-{user['age']}-{user['cancer_type'].split('_')[0]}"
    doc["birth_date"] = doc.pop('date_of_birth')
    doc["diagnostic_date"] = doc.pop('Year diagnostic')
    doc["description"] = doc.pop('Description')
    del doc["voluntari@s"]
    docs.append(doc)

mycol.insert_many(docs)
